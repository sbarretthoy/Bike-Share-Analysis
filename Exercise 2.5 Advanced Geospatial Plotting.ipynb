# %% [markdown]
# ## Exercise 2.5 Advanced Geospatial Plotting

# %% [markdown]
# 2. In a new notebook, import all necessary libraries and read in your data from the previous task.

# %%
pip install keplergl
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 60.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
# Using cached jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
# ...
#   Created wheel for keplergl: filename=keplergl-0.3.2-py2.py3-none-any.whl size=17922317 sha256=2f6c15f8053806c998fd34e591727b610ec480407090292b6c8eed9fea23c179
#   Stored in directory: /root/.cache/pip/wheels/e5/e9/db/b8b8f2fcb5cb1cd7268d88959fce267bc00697cb8f50dcd0d9
# Successfully built keplergl
# ...

# %%
# import libraries
import pandas as pd
import os
from keplergl import KeplerGl
from pyproj import CRS
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# 3. In the data set from the previous task, create a new column with the value of 1. Then create a new aggregated dataframe that contains 3 columns: starting station, ending station, and the count of trips between those stations.
#
# Done in Jupyter Lab and uploaded to CoLab

# %%
df = pd.read_csv('/content/drive/MyDrive/df_final_locations_for_map.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'start_station_name', 'end_station_name', 'start_lat',
#        'start_lng', 'end_lat', 'end_lng', 'value'],
#       dtype='object')

# %%
df.head()
# Out:
#    Unnamed: 0                 start_station_name  \
# 0     1414524             Central Park S & 6 Ave
# 1      642086         7 Ave & Central Park South
# 2     3794063           Roosevelt Island Tramway
# 3     2747279  Grand Army Plaza & Central Park S
# 4     1252913                 Broadway & W 58 St
#
#                     end_station_name  start_lat  start_lng    end_lat  \
# 0             Central Park S & 6 Ave  40.765909 -73.976342  40.765909
# 1         7 Ave & Central Park South  40.766741 -73.979069  40.766741
# 2           Roosevelt Island Tramway  40.757284 -73.953600  40.757284
# 3  Grand Army Plaza & Central Park S  40.764397 -73.973715  40.764397
# 4                 Broadway & W 58 St  40.766953 -73.981693  40.766953
#
#      end_lng  value
# 0 -73.976342  12480
# 1 -73.979069   8957
# 2 -73.953600   8283
# 3 -73.973715   7790
# 4 -73.981693   7443

# %% [markdown]
# 4. Initialize an instance of a kepler.gl map.

# %%
# Create KeplerGl instance
m = KeplerGl(height = 700, data={"data_1": df})
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter

# %%
m
# Out:
# KeplerGl(data={'data_1':      Unnamed: 0                 start_station_name  \
# 0       1414524             Cen…

# %%
from google.colab import output
output.enable_custom_widget_manager()

# %% [markdown]
# 5. Customize the output of your map—adjust the color of the points and add an arc that connects them. Pick a suitable color palette for each. In a Markdown section, explain what settings you changed and why.
#
# I made the start stations purple tthe the end stations yellow because there are a lot more start stations and the yellow would stand out against the purple. I also made the arc lines wider so they could be more easily seen.

# %%
m
# Out:
# KeplerGl(data={'data_1':      Unnamed: 0                 start_station_name  \
# 0       1414524             Cen…

# %% [markdown]
# 6. Add a filter to your map and use it to see what the most common trips are in New York City. What else makes an impression? For example, are there any zones that seem particularly busy? Using some additional research, write a few sentences to make sense of that output.
#
# Filtering to most trips the rides are fairly scattered but it seems the most rides are shorter trips in the business areas of New York City which also happen to be in the "touristy" areas of New York City and around the University. This may tell us that the member trips are people biking to and from work or school everyday and and casual trips are tourists getting around.

# %% [markdown]
# 7. Create a config object and save your map with it.

# %%
config = m.config

# %%
config
# Out:
# {'version': 'v1',
#  'config': {'visState': {'filters': [{'dataId': ['data_1'],
#      'id': 'snrguy72',
#      'name': ['value'],
#      'type': 'range',
#      'value': [1215, 1649],
#      'enlarged': False,
#      'plotType': 'histogram',
#      'animationWindow': 'free',
#      'yAxis': None,
#      'speed': 1}],
#    'layers': [{'id': 'j3s4avn',
#      'type': 'point',
#      'config': {'dataId': 'data_1',
#       'label': 'start',
#       'color': [130, 13, 175],
#       'highlightColor': [252, 242, 26, 255],
#       'columns': {'lat': 'start_lat', 'lng': 'start_lng', 'altitude': None},
#       'isVisible': True,
#       'visConfig': {'radius': 10,
#        'fixedRadius': False,
#        'opacity': 0.8,
#        'outline': False,
#        'thickness': 2,
#        'strokeColor': None,
#        'colorRange': {'name': 'Global Warming',
#         'type': 'sequential',
#         'category': 'Uber',
#         'colors': ['#5A1846',
#          '#900C3F',
#          '#C70039',
# ...

# %%
m.save_to_html(file_name='New York Bike Trips Aggregated.html', read_only = False, config = config)
# Out:
# Map saved to New York Bike Trips Aggregated.html!

# %%
import json
with open("config.json", "w") as outfile:
    json.dump(config, outfile)
