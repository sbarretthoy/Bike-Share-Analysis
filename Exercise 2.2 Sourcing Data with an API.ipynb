# %% [markdown]
# # Exercise 2 Sourcing data with an API

# %% [markdown]
# ## Import and concatenate

# %% [markdown]
# 4. In a new notebook, import all necessary libraries, read in your data, and join it. Hint: what’s the most effective way to import and join data in such a format?

# %%
import pandas as pd 
import numpy as np
import os 
import requests
import json
from datetime import datetime

# %%
# Create a list with all files in the folder using a list compehension

folderpath = r'Data'
filepaths  = [os.path.join(folderpath, name) for name in os.listdir(folderpath)]

# %%
filepaths
# Out:
# ['Data/202208-citibike-tripdata_3.csv',
#  'Data/202208-citibike-tripdata_2.csv',
#  'Data/202210-citibike-tripdata_4.csv',
#  'Data/202208-citibike-tripdata_1.csv',
#  'Data/202210-citibike-tripdata_1.csv',
#  'Data/.DS_Store',
#  'Data/202208-citibike-tripdata_4.csv',
#  'Data/202203-citibike-tripdata_2.csv',
#  'Data/202210-citibike-tripdata_2.csv',
#  'Data/202203-citibike-tripdata_1.csv',
#  'Data/202210-citibike-tripdata_3.csv',
#  'Data/202204-citibike-tripdata_1.csv',
#  'Data/202204-citibike-tripdata_2.csv',
#  'Data/202204-citibike-tripdata_3.csv',
#  'Data/202211-citibike-tripdata_3.csv',
#  'Data/202202-citibike-tripdata_1.csv',
#  'Data/202206-citbike-tripdata_1.csv',
#  'Data/202211-citibike-tripdata_2.csv',
#  'Data/202202-citibike-tripdata_2.csv',
#  'Data/202209-citibike-tripdata_4.csv',
#  'Data/202206-citbike-tripdata_2.csv',
#  'Data/202206-citbike-tripdata_3.csv',
#  'Data/202211-citibike-tripdata_1.csv',
#  'Data/202209-citibike-tripdata_1.csv',
# ...

# %%
# Read and concatenate all files simultaneously

df = pd.concat((pd.read_csv(f,encoding= 'unicode_escape') for f in filepaths), ignore_index = True)
# Out:
# /var/folders/wd/xh8m0hc916l1ffmsssspd3f40000gn/T/ipykernel_68898/1533451277.py:3: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.concat((pd.read_csv(f,encoding= 'unicode_escape') for f in filepaths), ignore_index = True)
# /var/folders/wd/xh8m0hc916l1ffmsssspd3f40000gn/T/ipykernel_68898/1533451277.py:3: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.concat((pd.read_csv(f,encoding= 'unicode_escape') for f in filepaths), ignore_index = True)
# /var/folders/wd/xh8m0hc916l1ffmsssspd3f40000gn/T/ipykernel_68898/1533451277.py:3: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.concat((pd.read_csv(f,encoding= 'unicode_escape') for f in filepaths), ignore_index = True)
# ...

# %%
df.shape
# Out:
# (30689921, 14)

# %%
df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  DF208007EE5F9D79   classic_bike  2022-08-26 15:21:44  2022-08-26 15:34:20
# 1  48A796B4996BACB0  electric_bike  2022-08-03 12:56:29  2022-08-03 13:06:10
# 2  AE459F435C0B1D5B   classic_bike  2022-08-11 17:49:47  2022-08-11 18:05:08
# 3  CA8B4A94620E74C0  electric_bike  2022-08-10 17:25:41  2022-08-10 17:35:23
# 4  EB85C6F0148BC348   classic_bike  2022-08-31 13:47:12  2022-08-31 14:24:00
#
#            start_station_name start_station_id  \
# 0         Berkeley Pl & 6 Ave          4134.06
# 1               21 St & 4 Ave          3668.04
# 2         48 St & Barnett Ave          6358.05
# 3  7 Ave & Central Park South          6912.01
# 4       Jerome Ave & W 195 St          8653.09
#
#                    end_station_name end_station_id  start_lat  start_lng  \
# 0                Windsor Pl & 8 Ave        3620.02  40.676530 -73.978469
# ...

# %%
df.tail()
# Out:
#                    ride_id  rideable_type           started_at  \
# 30689916  CB2EE50F60A58C7B   classic_bike  2022-12-12 08:38:46
# 30689917  3C0DF3280FEB1350   classic_bike  2022-12-12 13:06:32
# 30689918  B916E63B630D5020   classic_bike  2022-12-18 01:15:22
# 30689919  21EAC007BE7D4161   classic_bike  2022-12-08 23:09:54
# 30689920  538408C4A16F4415  electric_bike  2022-12-21 07:26:14
#
#                      ended_at                 start_station_name  \
# 30689916  2022-12-12 08:46:12  E 41 St & Madison Ave (SW corner)
# 30689917  2022-12-12 13:19:58               Peck Slip & South St
# 30689918  2022-12-18 01:48:15  E 41 St & Madison Ave (SW corner)
# 30689919  2022-12-08 23:26:37                   W 37 St & 10 Ave
# 30689920  2022-12-21 07:31:40                   W 37 St & 10 Ave
#
#          start_station_id         end_station_name end_station_id  start_lat  \
# 30689916          6474.12          6 Ave & W 33 St        6364.07  40.752165
# ...

# %% [markdown]
# 5. For this we read and joined the data in one code, the data used is very large and there are multiple csvs. So this way we do not need to read each file indivually and then join it. Instead, we nest the read function inside the concat function which reads the files and runs it though concat and joins them vertically in one code.

# %% [markdown]
# ## Get weather data using NOAA's API

# %% [markdown]
# 6. Register to NOAA’s web app and request your token.

# %%
# Define your NOAA token

Token = 'LUerFypcNUhSSclEcXlbACTgDLliKXJg'

# %% [markdown]
# 7. Obtain weather data from New York LaGuardia’s weather station for 2022 and export it to a CSV file.

# %%
# Get the API 

r = requests.get('https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&datatypeid=TAVG&limit=1000&stationid=GHCND:USW00014732&startdate=2022-01-01&enddate=2022-12-31', headers={'token':Token})

# %%
# Load the api response as a json

d = json.loads(r.text)

# %%
d
# Out:
# {'metadata': {'resultset': {'offset': 1, 'count': 365, 'limit': 1000}},
#  'results': [{'date': '2022-01-01T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00014732',
#    'attributes': 'H,,S,',
#    'value': 116},
#   {'date': '2022-01-02T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00014732',
#    'attributes': 'H,,S,',
#    'value': 114},
#   {'date': '2022-01-03T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00014732',
#    'attributes': 'H,,S,',
#    'value': 14},
#   {'date': '2022-01-04T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00014732',
#    'attributes': 'H,,S,',
#    'value': -27},
#   {'date': '2022-01-05T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00014732',
#    'attributes': 'H,,S,',
#    'value': 32},
#   {'date': '2022-01-06T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00014732',
#    'attributes': 'H,,S,',
#    'value': 49},
#   {'date': '2022-01-07T00:00:00',
# ...

# %%
# Secure all items in the response that correspond to TAVG

avg_temps = [item for item in d['results'] if item['datatype']=='TAVG']

# %%
# Get only the date field from all average temperature readings

dates_temp = [item['date'] for item in avg_temps]

# %%
# Get the temperature from all average temperature readings

temps = [item['value'] for item in avg_temps]

# %%
temps
# Out:
# [116,
#  114,
#  14,
#  -27,
#  32,
#  49,
#  7,
#  -25,
#  14,
#  16,
#  -54,
#  -19,
#  40,
#  48,
#  -67,
#  -80,
#  39,
#  18,
#  32,
#  51,
#  -60,
#  -59,
#  -7,
#  -2,
#  36,
#  -23,
#  -42,
#  1,
#  -48,
#  -71,
#  -34,
#  -17,
#  23,
#  64,
#  58,
#  -28,
#  -48,
#  5,
#  41,
#  28,
#  63,
#  86,
#  118,
#  28,
#  -43,
#  -47,
#  16,
#  116,
#  99,
#  1,
#  -26,
#  41,
#  56,
#  144,
#  11,
#  8,
#  -11,
#  24,
#  8,
#  26,
#  77,
#  56,
#  -19,
#  31,
#  96,
#  182,
#  87,
#  32,
#  40,
#  72,
#  51,
#  -23,
#  53,
#  116,
#  136,
#  82,
#  139,
#  131,
#  143,
#  104,
#  107,
#  72,
#  57,
#  96,
#  104,
#  59,
#  -15,
#  -12,
#  26,
#  99,
#  131,
#  72,
#  70,
#  76,
#  97,
#  86,
#  91,
#  128,
#  114,
#  86,
#  88,
#  134,
#  154,
#  163,
#  157,
#  157,
#  83,
#  79,
#  76,
#  94,
#  106,
#  146,
#  133,
#  128,
#  104,
#  115,
#  116,
#  82,
#  104,
#  129,
#  136,
#  121,
#  124,
#  120,
#  172,
#  148,
#  100,
#  104,
#  135,
#  154,
#  161,
#  171,
#  160,
# ...

# %%
# Put the results in a dataframe

df_temp = pd.DataFrame()

# %%
# Get only date and cast it to date time; convert temperature from tenths of Celsius to normal Celsius

df_temp['date'] = [datetime.strptime(d, "%Y-%m-%dT%H:%M:%S") for d in dates_temp]
df_temp['avgTemp'] = [float(v)/10.0 for v in temps]

# %%
df_temp.head()
# Out:
#         date  avgTemp
# 0 2022-01-01     11.6
# 1 2022-01-02     11.4
# 2 2022-01-03      1.4
# 3 2022-01-04     -2.7
# 4 2022-01-05      3.2

# %%
df_temp.tail()
# Out:
#           date  avgTemp
# 360 2022-12-27     -0.7
# 361 2022-12-28      3.4
# 362 2022-12-29      6.4
# 363 2022-12-30      9.3
# 364 2022-12-31      8.2

# %%
df.dtypes
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# Unnamed: 0             object
# dtype: object

# %%
df_temp.dtypes
# Out:
# date       datetime64[ns]
# avgTemp           float64
# dtype: object

# %%
df['started_at'] = pd.to_datetime(df['started_at'], dayfirst = True, format='mixed')

# %%
df['date'] = pd.to_datetime(df['started_at'], format='%Y-%m-%d').dt.date

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.dtypes
# Out:
# ride_id                       object
# rideable_type                 object
# started_at            datetime64[ns]
# ended_at                      object
# start_station_name            object
# start_station_id              object
# end_station_name              object
# end_station_id                object
# start_lat                    float64
# start_lng                    float64
# end_lat                      float64
# end_lng                      float64
# member_casual                 object
# Unnamed: 0                    object
# date                  datetime64[ns]
# dtype: object

# %% [markdown]
# 8. Merge the weather data with the New York CitiBike data set and export it to a CSV file.

# %%
# %%time
df_merged = df.merge(df_temp, how = 'left', on = 'date', indicator = True)
# Out:
# CPU times: user 6.88 s, sys: 29.5 s, total: 36.4 s
# Wall time: 5min 35s

# %%
df_merged.head()
# Out:
#             ride_id  rideable_type          started_at             ended_at  \
# 0  DF208007EE5F9D79   classic_bike 2022-08-26 15:21:44  2022-08-26 15:34:20
# 1  48A796B4996BACB0  electric_bike 2022-08-03 12:56:29  2022-08-03 13:06:10
# 2  AE459F435C0B1D5B   classic_bike 2022-08-11 17:49:47  2022-08-11 18:05:08
# 3  CA8B4A94620E74C0  electric_bike 2022-08-10 17:25:41  2022-08-10 17:35:23
# 4  EB85C6F0148BC348   classic_bike 2022-08-31 13:47:12  2022-08-31 14:24:00
#
#            start_station_name start_station_id  \
# 0         Berkeley Pl & 6 Ave          4134.06
# 1               21 St & 4 Ave          3668.04
# 2         48 St & Barnett Ave          6358.05
# 3  7 Ave & Central Park South          6912.01
# 4       Jerome Ave & W 195 St          8653.09
#
#                    end_station_name end_station_id  start_lat  start_lng  \
# 0                Windsor Pl & 8 Ave        3620.02  40.676530 -73.978469
# 1              Degraw St & Smith St        4298.05  40.662584 -73.995554
# ...

# %%
df_merged = df_merged.drop(columns = ['Unnamed: 0'])

# %%
df_merged.head()
# Out:
#             ride_id  rideable_type          started_at             ended_at  \
# 0  DF208007EE5F9D79   classic_bike 2022-08-26 15:21:44  2022-08-26 15:34:20
# 1  48A796B4996BACB0  electric_bike 2022-08-03 12:56:29  2022-08-03 13:06:10
# 2  AE459F435C0B1D5B   classic_bike 2022-08-11 17:49:47  2022-08-11 18:05:08
# 3  CA8B4A94620E74C0  electric_bike 2022-08-10 17:25:41  2022-08-10 17:35:23
# 4  EB85C6F0148BC348   classic_bike 2022-08-31 13:47:12  2022-08-31 14:24:00
#
#            start_station_name start_station_id  \
# 0         Berkeley Pl & 6 Ave          4134.06
# 1               21 St & 4 Ave          3668.04
# 2         48 St & Barnett Ave          6358.05
# 3  7 Ave & Central Park South          6912.01
# 4       Jerome Ave & W 195 St          8653.09
#
#                    end_station_name end_station_id  start_lat  start_lng  \
# 0                Windsor Pl & 8 Ave        3620.02  40.676530 -73.978469
# 1              Degraw St & Smith St        4298.05  40.662584 -73.995554
# ...

# %%
df_merged['_merge'].value_counts(dropna = False)
# Out:
# _merge
# both          30689921
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
df_merged.to_csv('newyork_data.csv')
